# %% [markdown]
# ### Edge detection

# %%
import cv2 as cv
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# This example is adapted from the [documentation for OpenCV](https://docs.opencv.org/5.0/index.html). The docs have many similar examples of working with images using the OpenCV Python library.

# %% [markdown]
# First we'll read in an image to the variable image. This example is taken from the [photo of Caroline Bassett](https://www.cdh.cam.ac.uk/about/people/caroline-bassett) on the CDH People page. We'll try to pull it in from the Core 2 GitHub repo. If you want to try this with your own images you'll need to upload them manually, but the rest of the code will be the same.

# %%
# !wget https://github.com/CambridgeDH/Core2-2026/blob/main/workshops/workshop_2/Caroline_image.jpg https://github.com/CambridgeDH/Core2-2026/blob/main/workshops/workshop_2/jonathan-blaney-friendly-740x740.jpg

# %%
image = cv.imread('Caroline_image.jpg')

# %% [markdown]
# We'll read the image into a variable called `image`. Pulling images into Colab can be a little bit hit-and-miss so first we'll check that our image displays as an image:

# %%
image

# %% [markdown]
# If you see an image of Caroline here, then please skip the next three cells. If you don't see an image we'll try getting it directly from the CDH website. We want to do this as a second choice because if we all hit the CDH site at the same time it will probably be flagged as suspicious activity and blocked.

# %%
# !rm *.jpg
# !wget https://www.cdh.cam.ac.uk/wp-content/uploads/2022/03/Caroline_image.jpg
# !wget https://www.cdh.cam.ac.uk/wp-content/uploads/2022/08/jonathan-blaney-friendly-740x740.jpg

# %% [markdown]
# Let's check again that we have an image:

# %%
image

# %% [markdown]
# If you see Caroline you can now run an edge detection algorithm developed by John F. Canny and named after him. You can set a minimum and maximum value for what counts as an edge. We'll start with 100 and 200.

# %%
min = 100
max = 200
edges = cv.Canny(image,min,max)
edges

# %% [markdown]
# Please now try varying the numbers for min and max in the cell above. You can put anything you like as long as they are integers and min is less than max.

# %%
plt.subplot(121),plt.imshow(image,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# For a colour image, which we should have acquired at the same time as the black-and-white picture of Caroline, we can follow the same process but notice that the colours don't look right!

# %%
jonathan_garish = cv.imread('jonathan-blaney-friendly-740x740.jpg')

# %%
jonathan_garish

# %% [markdown]
# This is a more complex image, with lots of background objects. How does that affect edge detection? Again, you can play around with the numbers.

# %%
min = 50
max = 200
edges = cv.Canny(jonathan_garish,min,max)
edges

# %% [markdown]
# You may not want to keep this particular image, but this is how you would save it to a file if you did.

# %%
cv.imwrite("jonathan-edges.png", edges)
